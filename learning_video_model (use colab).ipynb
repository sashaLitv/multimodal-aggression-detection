# %%
# !pip install ultralytics

# %%
import sys
import os
from google.colab import drive

drive.mount('/content/drive')
PROJECT_ROOT = '/content/drive/MyDrive/Cursova'

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

import src.modules.video.video_preprocess.video_preprocess as video_preprocess
import src.modules.video.video_train as video_train
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Системний шрифт не знайдено, кирилиця може не відображатись!

# %%
import importlib
importlib.reload(video_preprocess)
importlib.reload(video_train)
# Out:
# <module 'src.modules.video.video_train' from '/content/drive/MyDrive/Cursova/src/modules/video/video_train.py'>

# %%
result = video_train.run()
